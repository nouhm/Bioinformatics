# %%
def NTribonacciNb(n):
  arr = [0,1,1]

  for i in range(3, n+):
    arr.append((arr[i-1] + arr[i-2] + arr[i-3]))
  
  return arr[n-1]

# %%
NTribonacciNb(4)
# Out:
# 2

# %%
NTribonacciNb(25)
# Out:
# 755476
